# %% [markdown]
# # Annotation of data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("results.csv")

# %%
cx = pd.read_csv("contexts.csv")

# %%
df = df.drop(["source", "is_filler"], axis = 1)
df.head()
# Out:
#                             participant  cs          word  \
# 0  277a058c-6372-4840-8b1d-2ac2bac3d5e1  36        наглый
# 1  277a058c-6372-4840-8b1d-2ac2bac3d5e1  36        наглый
# 2  277a058c-6372-4840-8b1d-2ac2bac3d5e1  36        наглый
# 3  277a058c-6372-4840-8b1d-2ac2bac3d5e1  37  внимательный
# 4  277a058c-6372-4840-8b1d-2ac2bac3d5e1  37  внимательный
#
#                      group     contexts
# 0  proximal_proximal_meton      243 244
# 1  proximal_proximal_meton      245 246
# 2  proximal_proximal_meton  248 249 247
# 3  proximal_proximal_meton      250 252
# 4  proximal_proximal_meton  256 251 254

# %%
d = dict(zip(cx.id,cx.derivation)) #dictionary with key - stimulusID : value - derivation

# %%
d_sent = dict(zip(cx.id,cx.text))

# %%
def context_split(basket):
    basket_split =  [word.split() for word in basket]
    new_basket = [[int(stimulus) for stimulus in stimuli] for stimuli in basket_split]
    return new_basket

df.contexts = context_split(df.contexts)

# %%
df.head(2) # now column context is a list of integers, not a string
# Out:
#                             participant  cs    word                    group  \
# 0  277a058c-6372-4840-8b1d-2ac2bac3d5e1  36  наглый  proximal_proximal_meton
# 1  277a058c-6372-4840-8b1d-2ac2bac3d5e1  36  наглый  proximal_proximal_meton
#
#      contexts
# 0  [243, 244]
# 1  [245, 246]

# %%
cx.head()
# Out:
#    id  cs derivation                                               text
# 0   1   1   metonymy                 У него были маленькие злые глазки.
# 1   9   2   homonym1  Повышение по службе дало надежды на карьерный ...
# 2  18   3    literal   В этом году английский у нас преподает нервна...
# 3  25   4   homonym1  Наша задача ― посеять на лугах и пастбищах нов...
# 4  32   5    literal  В ходе расследования выяснилось, что водитель ...

# %%
labels = [[d[stimulus] for stimulus in stimuli] for stimuli in df.contexts]

# %%
pd_labels = pd.Series(labels)

# %%
df["labels"] = pd_labels

# %% [markdown]
# One line = one basket. The column *labels* contains the array tht represents a basket with the word sences

# %%
df.labels = [[sense.strip() for sense in senses] for senses in df.labels]

# %%
df.head(20)
# Out:
#                              participant  cs          word  \
# 0   277a058c-6372-4840-8b1d-2ac2bac3d5e1  36        наглый
# 1   277a058c-6372-4840-8b1d-2ac2bac3d5e1  36        наглый
# 2   277a058c-6372-4840-8b1d-2ac2bac3d5e1  36        наглый
# 3   277a058c-6372-4840-8b1d-2ac2bac3d5e1  37  внимательный
# 4   277a058c-6372-4840-8b1d-2ac2bac3d5e1  37  внимательный
# 5   277a058c-6372-4840-8b1d-2ac2bac3d5e1  37  внимательный
# 6   277a058c-6372-4840-8b1d-2ac2bac3d5e1  37  внимательный
# 7   277a058c-6372-4840-8b1d-2ac2bac3d5e1   6       строгий
# 8   277a058c-6372-4840-8b1d-2ac2bac3d5e1   6       строгий
# 9   277a058c-6372-4840-8b1d-2ac2bac3d5e1   6       строгий
# 10  277a058c-6372-4840-8b1d-2ac2bac3d5e1  38       наивный
# 11  277a058c-6372-4840-8b1d-2ac2bac3d5e1  38       наивный
# 12  277a058c-6372-4840-8b1d-2ac2bac3d5e1  38       наивный
# 13  277a058c-6372-4840-8b1d-2ac2bac3d5e1  31   беспокойный
# 14  277a058c-6372-4840-8b1d-2ac2bac3d5e1  31   беспокойный
# 15  277a058c-6372-4840-8b1d-2ac2bac3d5e1  31   беспокойный
# 16  277a058c-6372-4840-8b1d-2ac2bac3d5e1  30    любопытный
# 17  277a058c-6372-4840-8b1d-2ac2bac3d5e1  30    любопытный
# 18  6d95f5d4-7b88-48f9-b239-b7db98ace329  24   беззаботный
# 19  6d95f5d4-7b88-48f9-b239-b7db98ace329  24   беззаботный
#
#                       group                        contexts  \
# 0   proximal_proximal_meton                      [243, 244]
# 1   proximal_proximal_meton                      [245, 246]
# 2   proximal_proximal_meton                 [248, 249, 247]
# 3   proximal_proximal_meton                      [250, 252]
# 4   proximal_proximal_meton                 [256, 251, 254]
# 5   proximal_proximal_meton                      [253, 255]
# 6   proximal_proximal_meton                           [257]
# 7            proximal_meton                        [40, 39]
# 8            proximal_meton                        [42, 43]
# 9            proximal_meton                        [41, 44]
# 10  proximal_proximal_meton                      [258, 262]
# 11  proximal_proximal_meton            [264, 260, 261, 263]
# 12  proximal_proximal_meton                      [265, 259]
# 13    proximal_distal_meton                 [209, 210, 205]
# 14    proximal_distal_meton                      [211, 206]
# 15    proximal_distal_meton                 [208, 212, 207]
# 16    proximal_distal_meton                      [203, 199]
# 17    proximal_distal_meton            [200, 201, 202, 204]
# 18    proximal_distal_meton  [152, 153, 154, 156, 157, 158]
# 19    proximal_distal_meton                 [159, 155, 151]
#
#                                                labels
# 0                                  [literal, literal]
# 1          [proximal_metonymy_1, proximal_metonymy_1]
# 2   [proximal_proximal_metonymy_2, proximal_proxim...
# 3          [proximal_metonymy_1, proximal_metonymy_1]
# 4    [proximal_proximal_metonymy_2, literal, literal]
# 5   [proximal_proximal_metonymy_2, proximal_proxim...
# 6                      [proximal_proximal_metonymy_2]
# 7                                  [literal, literal]
# 8                                [metaphor, metaphor]
# 9                                [metonymy, metonymy]
# 10                                 [literal, literal]
# 11  [proximal_metonymy_1, proximal_metonymy_1, pro...
# 12  [proximal_proximal_metonymy_2, proximal_proxim...
# 13                [literal, metonymy_distal, literal]
# 14             [metonymy_proximal, metonymy_proximal]
# 15        [metonymy_distal, metonymy_distal, literal]
# 16                 [metonymy_distal, metonymy_distal]
# 17  [metonymy_proximal, metonymy_proximal, literal...
# 18  [literal, metonymy_distal, literal, metonymy_d...
# 19  [metonymy_proximal, metonymy_proximal, metonym...

# %% [markdown]
# The function that annotates the types of baskets:
#     1. Clean baskets, where all words belong to the same sence: e.g., [proximal_metonymy, proximal_metonymy]
#     2. Baskets with only one stimulus: e.g. [literal] or [proximal_metonymy]
#     3. Mixed baskets where the words belong to at least two different sences: e.g. [literal, literal, proximal_metonymy] or [metphor, metaphor, literal, proximal_metonymy] or [metaphor, literal]

# %%
arr = []
for basket in df.labels:
    if (len(basket)>1 and (len(set(basket))==1)):
        arr.append("pure") # clean baskets, where all words belong to the same sence 
    elif len(basket) == 1:
        arr.append("one stimulus") # baskets with only one stimulus
    else:
        arr.append("mixed") # mixed baskets where the words belong to different sences

# %%
df["basket_type"] = arr

# %%
df.to_csv('output.csv')
